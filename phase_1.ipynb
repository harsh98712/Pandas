# %% [markdown]
# creating series

# %%
import numpy as np
import pandas as pd

# %%
arr = np.array([1, 2, 3])
harsh_list = [25, 36, 14]
d = {1:10, 2:20, 3:30}
lables = ['a','b','c']
pd.Series(harsh_list)
pd.Series(harsh_list,index=lables)
# Out:
# a    25
# b    36
# c    14
# dtype: int64
