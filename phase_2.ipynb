# %%
import numpy as np
import pandas as pd

# %% [markdown]
# CREATING DATAFRAMES

# %%
data = {
    'Name': ['John', 'Krish', 'harman', 'rai'],
    'Age': [21, 19, 21, 21],
    'City': ['basi', 'police line', 'bajwara', 'jct'],
    'Salary': [65000, 70000, 62000, 85000]
}
df = pd.DataFrame(data)
df
# Out:
#      Name  Age         City  Salary
# 0    John   21         basi   65000
# 1   Krish   19  police line   70000
# 2  harman   21      bajwara   62000
# 3     rai   21          jct   85000

# %%
data_list = {
    'Name': ['John', 'Krish', 'harman', 'rai'],
    'Age': [21, 19, 21, 21],
    'City': ['basi', 'police line', 'bajwara', 'jct'],
    'Salary': [65000, 70000, 62000, 85000]
}
df = pd.DataFrame(data)
df2 = pd.DataFrame(data_list)
columns = ["Name","Age","City","Salary"]
df2 = pd.DataFrame(data_list,columns =columns)
df2
# Out:
#      Name  Age         City  Salary
# 0    John   21         basi   65000
# 1   Krish   19  police line   70000
# 2  harman   21      bajwara   62000
# 3     rai   21          jct   85000

# %% [markdown]
# SELECTING AND INDEXING

# %%
df
# Out:
#      Name  Age         City  Salary
# 0    John   21         basi   65000
# 1   Krish   19  police line   70000
# 2  harman   21      bajwara   62000
# 3     rai   21          jct   85000

# %%
df[["Name","Salary"]]
# Out:
#      Name  Salary
# 0    John   65000
# 1   Krish   70000
# 2  harman   62000
# 3     rai   85000

# %%
#creating s new column

df["accupation"] = ["doctor","eng.","doctor","eng."]
df
# Out:
#      Name  Age         City  Salary accupation
# 0    John   21         basi   65000     doctor
# 1   Krish   19  police line   70000       eng.
# 2  harman   21      bajwara   62000     doctor
# 3     rai   21          jct   85000       eng.

# %%
#deleting the column
df.drop('accupation', axis= 1)
# Out:
#      Name  Age         City  Salary
# 0    John   21         basi   65000
# 1   Krish   19  police line   70000
# 2  harman   21      bajwara   62000
# 3     rai   21          jct   85000

# %%
#inplace is used to delete the data permanently
#selecting the rows
df
df.loc[[0,1]]
# Out:
#     Name  Age         City  Salary accupation
# 0   John   21         basi   65000     doctor
# 1  Krish   19  police line   70000       eng.

# %%
#selecting the subsets of rows and column
df.loc[[2,3]][["Age","Salary"]]
# Out:
#    Age  Salary
# 2   21   62000
# 3   21   85000

# %%
#conditional selection
df[df["Age"]>20]
# Out:
#      Name  Age     City  Salary accupation
# 0    John   21     basi   65000     doctor
# 2  harman   21  bajwara   62000     doctor
# 3     rai   21      jct   85000       eng.
