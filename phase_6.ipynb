# %%
import numpy as np
import pandas as pd

# %% [markdown]
# PIVOT TABLES

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    520     49   John  January      Q1
# 1  2023-01-02       B   West    713     88   Mary  January      Q1
# 2  2023-01-03       C  North    239     14    Bob  January      Q1
# 3  2023-01-04       D  South    399     82  Alice  January      Q1
# 4  2023-01-05       A   East    781     56   John  January      Q1
# 5  2023-01-06       B   West    123     54   Mary  January      Q1
# 6  2023-01-07       C  North    581     53    Bob  January      Q1
# 7  2023-01-08       D  South    306     57  Alice  January      Q1
# 8  2023-01-09       A   East    838     91   John  January      Q1
# 9  2023-01-10       B   West    338     48   Mary  January      Q1
# 10 2023-01-11       C  North    825     22    Bob  January      Q1
# 11 2023-01-12       D  South    443     54  Alice  January      Q1
# 12 2023-01-13       A   East    487     13   John  January      Q1
# 13 2023-01-14       B   West    136     19   Mary  January      Q1
# 14 2023-01-15       C  North    909     63    Bob  January      Q1
# 15 2023-01-16       D  South    603     67  Alice  January      Q1
# 16 2023-01-17       A   East    586     60   John  January      Q1
# 17 2023-01-18       B   West    861     80   Mary  January      Q1
# 18 2023-01-19       C  North    614     71    Bob  January      Q1
# 19 2023-01-20       D  South    281     77  Alice  January      Q1

# %%
pd.pivot_table(df,values = "Sales",index = 'Region',columns="Product",aggfunc = 'median')
# Out:
# Product      A      B      C      D
# Region
# East     586.0    NaN    NaN    NaN
# North      NaN    NaN  614.0    NaN
# South      NaN    NaN    NaN  399.0
# West       NaN  338.0    NaN    NaN

# %%
pivot2 = pd.pivot_table(df, values=['Sales', 'Units'], index='Region', columns='Product')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     642.4    NaN    NaN    NaN  53.8   NaN   NaN   NaN
# North      NaN    NaN  633.6    NaN   NaN   NaN  44.6   NaN
# South      NaN    NaN    NaN  406.4   NaN   NaN   NaN  67.4
# West       NaN  434.2    NaN    NaN   NaN  57.8   NaN   NaN

# %% [markdown]
# cross tabs

# %%
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
